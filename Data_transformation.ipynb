# %% [markdown]
# <a href="https://colab.research.google.com/github/ranipriyanka20/ores_5160-03/blob/main/Data_transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/content/My dataset.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.627   50    dead
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.627   50    dead
# ...

# %%
object_columns = df.select_dtypes(include=['object']).columns
df[object_columns] = df[object_columns].astype('category')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.627   50    dead
# ...

# %%
df['Age'] = df['Age'].astype(int)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.627   50    dead
# ...

# %%
df['BodyMassIndex'] = df['BMI'].astype(float)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age Outcome  BodyMassIndex
# ...

# %%
df = pd.read_csv('My dataset.csv',names = ['Num Pregnancies','Blood Glucose','Blood pressure','SkinThickness','InsulinLevel','BodyMassIndex','PedigreeScore','YearsOld','DiabetesOutcome'],header = 1)

# %%
df.head()
# Out:
#    Num Pregnancies  Blood Glucose  Blood pressure  SkinThickness  \
# 0                1             85              66             29
# 1                8            183              64              0
# 2                1             89              66             23
# 3                0            137              40             35
# 4                5            116              74              0
#
#    InsulinLevel  BodyMassIndex  PedigreeScore  YearsOld DiabetesOutcome
# 0             0           26.6          0.351        31           alive
# 1             0           23.3          0.672        32            dead
# 2            94           28.1          0.167        21           alive
# 3           168           43.1          2.288        33            dead
# 4             0           25.6          0.201        30           alive

# %%
df['GlucoseToBloodPressureRatio'] = df['Blood Glucose'] / df['Blood pressure']
df
# Out:
#      Num Pregnancies  Blood Glucose  Blood pressure  SkinThickness  \
# 0                  1             85              66             29
# 1                  8            183              64              0
# 2                  1             89              66             23
# 3                  0            137              40             35
# 4                  5            116              74              0
# ..               ...            ...             ...            ...
# 762               10            101              76             48
# 763                2            122              70             27
# 764                5            121              72             23
# 765                1            126              60              0
# 766                1             93              70             31
#
#      InsulinLevel  BodyMassIndex  PedigreeScore  YearsOld DiabetesOutcome  \
# 0               0           26.6          0.351        31           alive
# ...

# %%
df['DiabetesRiskScore'] = (df['Blood Glucose'] * 0.4) + (df['BodyMassIndex'] * 0.3) - (df['YearsOld'] * 0.1)
df
# Out:
#      Num Pregnancies  Blood Glucose  Blood pressure  SkinThickness  \
# 0                  1             85              66             29
# 1                  8            183              64              0
# 2                  1             89              66             23
# 3                  0            137              40             35
# 4                  5            116              74              0
# ..               ...            ...             ...            ...
# 762               10            101              76             48
# 763                2            122              70             27
# 764                5            121              72             23
# 765                1            126              60              0
# 766                1             93              70             31
#
#      InsulinLevel  BodyMassIndex  PedigreeScore  YearsOld DiabetesOutcome  \
# 0               0           26.6          0.351        31           alive
# ...

# %%
df['TotalInsulin'] = df['InsulinLevel'] * df['Num Pregnancies']
df
# Out:
#      Num Pregnancies  Blood Glucose  Blood pressure  SkinThickness  \
# 0                  1             85              66             29
# 1                  8            183              64              0
# 2                  1             89              66             23
# 3                  0            137              40             35
# 4                  5            116              74              0
# ..               ...            ...             ...            ...
# 762               10            101              76             48
# 763                2            122              70             27
# 764                5            121              72             23
# 765                1            126              60              0
# 766                1             93              70             31
#
#      InsulinLevel  BodyMassIndex  PedigreeScore  YearsOld DiabetesOutcome  \
# 0               0           26.6          0.351        31           alive
# ...

# %%
mean_glucose_by_age = df.groupby('YearsOld')['Blood Glucose'].mean()
df
# Out:
#      Num Pregnancies  Blood Glucose  Blood pressure  SkinThickness  \
# 0                  1             85              66             29
# 1                  8            183              64              0
# 2                  1             89              66             23
# 3                  0            137              40             35
# 4                  5            116              74              0
# ..               ...            ...             ...            ...
# 762               10            101              76             48
# 763                2            122              70             27
# 764                5            121              72             23
# 765                1            126              60              0
# 766                1             93              70             31
#
#      InsulinLevel  BodyMassIndex  PedigreeScore  YearsOld DiabetesOutcome  \
# 0               0           26.6          0.351        31           alive
# ...

# %%
df = df [['Num Pregnancies','Blood Glucose','Blood pressure','GlucoseToBloodPressureRatio','SkinThickness','InsulinLevel','BodyMassIndex','DiabetesRiskScore','TotalInsulin','PedigreeScore','YearsOld',	'DiabetesOutcome']]
df
# Out:
#      Num Pregnancies  Blood Glucose  Blood pressure  \
# 0                  1             85              66
# 1                  8            183              64
# 2                  1             89              66
# 3                  0            137              40
# 4                  5            116              74
# ..               ...            ...             ...
# 762               10            101              76
# 763                2            122              70
# 764                5            121              72
# 765                1            126              60
# 766                1             93              70
#
#      GlucoseToBloodPressureRatio  SkinThickness  InsulinLevel  BodyMassIndex  \
# 0                       1.287879             29             0           26.6
# 1                       2.859375              0             0           23.3
# 2                       1.348485             23            94           28.1
# ...

# %%
median_skin_thickness = df['SkinThickness'].median()
df['SkinThickness'].fillna(median_skin_thickness, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age Outcome  BodyMassIndex
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(data=df['BloodPressure'])
plt.xticks(rotation=45)
plt.show()
